# %%
import pandas as pd
from pathlib import Path

# adjust this to wherever your repo root actually is on disk
DATA_DIR = Path(r'C:\Personal\data\extracted')

# pick the shortest/simplest one to start with
df = pd.read_csv(DATA_DIR / 'ggpu121_2025-02-10_gpu-error_tidy.csv')

print('Shape:', df.shape)
print('Time range:', df['timeUtc'].min(), 'to', df['timeUtc'].max())
df.head()
# Out:
# C:\Users\DBUDHA\AppData\Local\Temp\ipykernel_16288\2722166355.py:8: DtypeWarning: Columns (0: device, 1: uuid, 2: modelName, 3: driverVersion) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(DATA_DIR / 'ggpu121_2025-02-10_gpu-error_tidy.csv')
# Shape: (630168, 11)
# Time range: 2025-02-03 00:00:00 to 2025-02-12 23:50:00
#                timeUtc               node  \
# 0  2025-02-06 16:40:00  node_2b08d249c0ba
# 1  2025-02-06 16:50:00  node_2b08d249c0ba
# 2  2025-02-06 17:00:00  node_2b08d249c0ba
# 3  2025-02-06 17:10:00  node_2b08d249c0ba
# 4  2025-02-06 17:20:00  node_2b08d249c0ba
#
#                                   metric  value  gpu   device  \
# 0  DCGM_FI_DEV_CORRECTABLE_REMAPPED_ROWS    0.0  1.0  nvidia1
# 1  DCGM_FI_DEV_CORRECTABLE_REMAPPED_ROWS    0.0  1.0  nvidia1
# 2  DCGM_FI_DEV_CORRECTABLE_REMAPPED_ROWS    0.0  1.0  nvidia1
# 3  DCGM_FI_DEV_CORRECTABLE_REMAPPED_ROWS    0.0  1.0  nvidia1
# ...
